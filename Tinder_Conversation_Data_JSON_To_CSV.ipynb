# %%
import json
import csv

# Function to extract the data from JSON and save to CSV
def json_to_csv(json_path, csv_path):
    # Read the JSON file
    with open(json_path, "r") as file:
        data = json.load(file)

    # Extract the required data
    csv_data = []

    for item in data:
        _id = item.get('_id', '')
        conversations = item.get('conversations', [])
    
        for convo in conversations:
            match_id = convo.get('match_id', '')
            messages = convo.get('messages', [])
        
            for msg in messages:
                message_text = msg.get('message')
                # Ensure the message text is valid and not None
                if message_text:
                    csv_data.append([_id, match_id, message_text])

    # Write the data to a CSV file
    with open(csv_path, "w", newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(['_id', 'match_id', 'message'])
        # Write the data
        writer.writerows(csv_data)
# Usage
json_path = "tinder_json_og.json"
csv_output_path = "Tinder_Conversation_Data.csv"
json_to_csv(json_path, csv_output_path)

# %% [markdown]
# **Conversation Data - Cleaning**

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re 
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Tinder_Conversation_Data.csv')

# %%
df.head()
# Out:
#                                 _id   match_id  \
# 0  024610702baf540af5637873cd1534e9  Match 464
# 1  024610702baf540af5637873cd1534e9  Match 463
# 2  024610702baf540af5637873cd1534e9  Match 463
# 3  024610702baf540af5637873cd1534e9  Match 462
# 4  024610702baf540af5637873cd1534e9  Match 462
#
#                                              message
# 0  Hello again, so now that we matched again, wha...
# 1  Most of the girls on this app scare me, but fo...
# 2  Dear diary, cute girl vanished... should I sen...
# 3  Most of the girls on this app scare me, but fo...
# 4  Well not many people have photos of dogs, and ...

# %%
df.shape
# Out:
# (2209979, 3)

# %%
from collections import Counter
import string


# Extract the 'message' column and concatenate the text
text = " ".join(df['message'].dropna())

# Tokenize the text (split by whitespace and remove punctuation)
translator = str.maketrans("", "", string.punctuation)
tokens = text.translate(translator).lower().split()

# Count the occurrences of each word
word_counts = Counter(tokens)

# %%
# Get the top 50 words
top_10_words = word_counts.most_common(10)

top_10_df = pd.DataFrame(top_10_words, columns=['word', 'count'])
top_10_df
# Out:
#   word   count
# 0    i  468459
# 1  you  378310
# 2    a  325890
# 3   to  304424
# 4  the  246500
# 5   in  186071
# 6  and  184023
# 7   it  133189
# 8   of  129062
# 9   so  124408

# %%
import re

# Function to check if a character is an emoji
def is_emoji(s):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F700-\U0001F77F"  # alchemical symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                               u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                               u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                               u"\U00002702-\U000027B0"  # Dingbats
                               u"\U000024C2-\U0001F251"  
                               "]+", flags=re.UNICODE)
    return re.search(emoji_pattern, s) is not None

# Extract emojis from the text
emojis = [char for char in text if is_emoji(char)]

# Count the occurrences of each emoji
emoji_counts = Counter(emojis)

# %%
top_emojis = emoji_counts.most_common(10)
top_emojis_df = pd.DataFrame(top_emojis, columns=['emoji', 'count'])
top_emojis_df
# Out:
#   emoji  count
# 0     😂  82073
# 1     😅  30137
# 2     ️  27690
# 3     😉  25775
# 4     😊  25448
# 5     😁  18728
# 6     😄  17414
# 7     🤔  12664
# 8     🙂  12411
# 9     😍  11920

# %% [markdown]
# Let's add gender to our dataset.

# %%
df2 = pd.read_csv('Tinder_Data_v3_Clean_Edition.csv')

# %%
# Merge the gender column from df2 into df using the _id column
df = df.merge(df2[['gender', '_id']], on='_id', how='left')

# %%
df.tail()
# Out:
#                                       _id match_id  \
# 2209974  81a844f3889e3859b777ef2ea4a07bb0  Match 2
# 2209975  81a844f3889e3859b777ef2ea4a07bb0  Match 2
# 2209976  81a844f3889e3859b777ef2ea4a07bb0  Match 1
# 2209977  81a844f3889e3859b777ef2ea4a07bb0  Match 1
# 2209978  81a844f3889e3859b777ef2ea4a07bb0  Match 1
#
#                                                    message gender
# 2209974          Muss jetzt jeden Tag kalorien zählen haha      M
# 2209975                       Habe jetzt aber ein home gym      M
# 2209976  https&colon;&sol;&sol;media.tenor.com&sol;imag...      M
# 2209977                                               Hey!      M
# 2209978    Na wie gehts dir? 😃 ich war bis eben in der Bib      M

# %% [markdown]
# Calculating length of characters of first message sent.

# %%
# Group by '_id' and 'match_id' and get the first message for each group
first_messages = df.groupby(['_id', 'match_id']).first().reset_index()

# Calculate the length of the first message for each group
first_messages['Opener'] = first_messages['message'].str.len()

# Merge the 'Opener' column back to the original df
df = df.merge(first_messages[['_id', 'match_id', 'Opener']], on=['_id', 'match_id'], how='left')

df.head()
# Out:
#                                 _id   match_id  \
# 0  024610702baf540af5637873cd1534e9  Match 464
# 1  024610702baf540af5637873cd1534e9  Match 463
# 2  024610702baf540af5637873cd1534e9  Match 463
# 3  024610702baf540af5637873cd1534e9  Match 462
# 4  024610702baf540af5637873cd1534e9  Match 462
#
#                                              message gender  Opener
# 0  Hello again, so now that we matched again, wha...      M      81
# 1  Most of the girls on this app scare me, but fo...      M     119
# 2  Dear diary, cute girl vanished... should I sen...      M     119
# 3  Most of the girls on this app scare me, but fo...      M     121
# 4  Well not many people have photos of dogs, and ...      M     121

# %%
df['Basic Opener'] = df['Opener'] <= 18

# %%
df.head()
# Out:
#                                 _id   match_id  \
# 0  024610702baf540af5637873cd1534e9  Match 464
# 1  024610702baf540af5637873cd1534e9  Match 463
# 2  024610702baf540af5637873cd1534e9  Match 463
# 3  024610702baf540af5637873cd1534e9  Match 462
# 4  024610702baf540af5637873cd1534e9  Match 462
#
#                                              message gender  Opener  \
# 0  Hello again, so now that we matched again, wha...      M      81
# 1  Most of the girls on this app scare me, but fo...      M     119
# 2  Dear diary, cute girl vanished... should I sen...      M     119
# 3  Most of the girls on this app scare me, but fo...      M     121
# 4  Well not many people have photos of dogs, and ...      M     121
#
#    Basic Opener
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
# Count the number of messages for each '_id' and 'match_id' group
conv_length = df.groupby(['_id', 'match_id']).size().reset_index(name='Conv Length')

# Merge the 'Conv Length' column back to the original df
df = df.merge(conv_length, on=['_id', 'match_id'], how='left')

# %%
df.head()
# Out:
#                                 _id   match_id  \
# 0  024610702baf540af5637873cd1534e9  Match 464
# 1  024610702baf540af5637873cd1534e9  Match 463
# 2  024610702baf540af5637873cd1534e9  Match 463
# 3  024610702baf540af5637873cd1534e9  Match 462
# 4  024610702baf540af5637873cd1534e9  Match 462
#
#                                              message gender  Opener  \
# 0  Hello again, so now that we matched again, wha...      M      81
# 1  Most of the girls on this app scare me, but fo...      M     119
# 2  Dear diary, cute girl vanished... should I sen...      M     119
# 3  Most of the girls on this app scare me, but fo...      M     121
# 4  Well not many people have photos of dogs, and ...      M     121
#
#    Basic Opener  Conv Length
# 0         False            1
# 1         False            2
# 2         False            2
# 3         False            4
# 4         False            4

# %%
data = df.drop_duplicates(subset='match_id', keep='first')

# %%
data['Gif Opener'] = data['message'].str.contains('giphy.com', case=False, na=False)
# Out:
# /var/folders/4n/1bbl6rhn7k19zzvlm8qjch480000gn/T/ipykernel_33032/4188779806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gif Opener'] = data['message'].str.contains('giphy.com', case=False, na=False)

# %%
data['question'] = data['message'].str.endswith('?', na=False)
# Out:
# /var/folders/4n/1bbl6rhn7k19zzvlm8qjch480000gn/T/ipykernel_33032/3532355848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['question'] = data['message'].str.endswith('?', na=False)

# %%
data['Pickup Line'] = (~data['message'].str.endswith('?', na=False)) & (data['Opener'] >= 19)
# Out:
# /var/folders/4n/1bbl6rhn7k19zzvlm8qjch480000gn/T/ipykernel_33032/878441531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Pickup Line'] = (~data['message'].str.endswith('?', na=False)) & (data['Opener'] >= 19)

# %%
data.head(50)
# Out:
#                                   _id   match_id  \
# 0    024610702baf540af5637873cd1534e9  Match 464
# 1    024610702baf540af5637873cd1534e9  Match 463
# 3    024610702baf540af5637873cd1534e9  Match 462
# 7    024610702baf540af5637873cd1534e9  Match 460
# 9    024610702baf540af5637873cd1534e9  Match 459
# 14   024610702baf540af5637873cd1534e9  Match 458
# 21   024610702baf540af5637873cd1534e9  Match 457
# 23   024610702baf540af5637873cd1534e9  Match 456
# 25   024610702baf540af5637873cd1534e9  Match 454
# 32   024610702baf540af5637873cd1534e9  Match 453
# 37   024610702baf540af5637873cd1534e9  Match 452
# 41   024610702baf540af5637873cd1534e9  Match 451
# 48   024610702baf540af5637873cd1534e9  Match 450
# 51   024610702baf540af5637873cd1534e9  Match 449
# 57   024610702baf540af5637873cd1534e9  Match 448
# 59   024610702baf540af5637873cd1534e9  Match 447
# 67   024610702baf540af5637873cd1534e9  Match 446
# 79   024610702baf540af5637873cd1534e9  Match 445
# 95   024610702baf540af5637873cd1534e9  Match 444
# 97   024610702baf540af5637873cd1534e9  Match 443
# 99   024610702baf540af5637873cd1534e9  Match 442
# 101  024610702baf540af5637873cd1534e9  Match 441
# 103  024610702baf540af5637873cd1534e9  Match 440
# 105  024610702baf540af5637873cd1534e9  Match 439
# 107  024610702baf540af5637873cd1534e9  Match 438
# 109  024610702baf540af5637873cd1534e9  Match 437
# 110  024610702baf540af5637873cd1534e9  Match 436
# 112  024610702baf540af5637873cd1534e9  Match 435
# 148  024610702baf540af5637873cd1534e9  Match 434
# 154  024610702baf540af5637873cd1534e9  Match 433
# 157  024610702baf540af5637873cd1534e9  Match 432
# 158  024610702baf540af5637873cd1534e9  Match 431
# 162  024610702baf540af5637873cd1534e9  Match 430
# 173  024610702baf540af5637873cd1534e9  Match 429
# 176  024610702baf540af5637873cd1534e9  Match 428
# 179  024610702baf540af5637873cd1534e9  Match 427
# 183  024610702baf540af5637873cd1534e9  Match 426
# 185  024610702baf540af5637873cd1534e9  Match 425
# 188  024610702baf540af5637873cd1534e9  Match 424
# 198  024610702baf540af5637873cd1534e9  Match 423
# 212  024610702baf540af5637873cd1534e9  Match 422
# 214  024610702baf540af5637873cd1534e9  Match 421
# 215  024610702baf540af5637873cd1534e9  Match 420
# 217  024610702baf540af5637873cd1534e9  Match 419
# 218  024610702baf540af5637873cd1534e9  Match 418
# 220  024610702baf540af5637873cd1534e9  Match 417
# 222  024610702baf540af5637873cd1534e9  Match 416
# 231  024610702baf540af5637873cd1534e9  Match 415
# 233  024610702baf540af5637873cd1534e9  Match 414
# 235  024610702baf540af5637873cd1534e9  Match 413
#
#                                                message gender  Opener  \
# 0    Hello again, so now that we matched again, wha...      M      81
# 1    Most of the girls on this app scare me, but fo...      M     119
# 3    Most of the girls on this app scare me, but fo...      M     121
# 7    https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     168
# 9    https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 14   https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 21                   Yeah, I was there for this summer      M      33
# 23   https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 25   https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     168
# 32   https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     101
# 37   Hi, I remember we matched before and traded sn...      M     101
# 41   https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 48   https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 51   https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     168
# 57   https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     168
# 59   https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     168
# 67   https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 79   https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 95   https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     168
# 97   You look cute, I&rsquo;d hold your hand in public      M      49
# 99   https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     168
# 101  https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     168
# 103  https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 105  https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 107  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     168
# 109    So what are you specifically competitive about?      M      47
# 110  https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     168
# 112          Sure, but I&rsquo;m going to guess nay-la      M      41
# 148  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     101
# 154  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     101
# 157                Hmm what do you like to do for fun?      M      35
# 158  You look cute, I&rsquo;d hold your hand in public      M      49
# 162  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     101
# 173  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     101
# 176  https&colon;&sol;&sol;media3.giphy.com&sol;med...      M     101
# 179  https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     101
# 183  https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     101
# 185  I like FDR bc he handled the Great Depression ...      M      92
# 188  Oh hey, I&rsquo;m also new to Richmond! Where ...      M      87
# 198  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     101
# 212  https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     101
# 214  When I scroll through your pics, it looks like...      M      67
# 215  https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     101
# 217  Since you&rsquo;re from out of the country, wh...      M      72
# 218  https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     101
# 220  https&colon;&sol;&sol;media0.giphy.com&sol;med...      M     101
# 222  https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     101
# 231  https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     101
# 233  https&colon;&sol;&sol;media1.giphy.com&sol;med...      M     101
# 235  https&colon;&sol;&sol;media2.giphy.com&sol;med...      M     101
#
#      Basic Opener  Conv Length  Gif Opener  question  Pickup Line
# 0           False            1       False      True        False
# 1           False            2       False     False         True
# 3           False            4       False     False         True
# 7           False            2        True     False         True
# 9           False            5        True     False         True
# 14          False            7        True     False         True
# 21          False            2       False     False         True
# 23          False            2        True     False         True
# 25          False            7        True     False         True
# 32          False            5        True     False         True
# 37          False            4       False     False         True
# 41          False            7        True     False         True
# 48          False            3        True     False         True
# 51          False            6        True     False         True
# 57          False            2        True     False         True
# 59          False            8        True     False         True
# 67          False           12        True     False         True
# 79          False           16        True     False         True
# 95          False            2        True     False         True
# 97          False            2       False     False         True
# 99          False            2        True     False         True
# 101         False            2        True     False         True
# 103         False            2        True     False         True
# 105         False            2        True     False         True
# 107         False            2        True     False         True
# 109         False            1       False      True        False
# 110         False            2        True     False         True
# 112         False           36       False     False         True
# 148         False            6        True     False         True
# 154         False            3        True     False         True
# 157         False            1       False      True        False
# 158         False            4       False     False         True
# 162         False           11        True     False         True
# 173         False            3        True     False         True
# 176         False            3        True     False         True
# 179         False            4        True     False         True
# 183         False            2        True     False         True
# 185         False            3       False     False         True
# 188         False           10       False      True        False
# 198         False           14        True     False         True
# 212         False            2        True     False         True
# 214         False            1       False     False         True
# 215         False            2        True     False         True
# 217         False            1       False      True        False
# 218         False            2        True     False         True
# 220         False            2        True     False         True
# 222         False            9        True     False         True
# 231         False            2        True     False         True
# 233         False            2        True     False         True
# 235         False            9        True     False         True

# %%
true_count = data['Basic Opener'].sum()
print(true_count)
# Out:
# 6712

# %%
data.shape
# Out:
# (12464, 10)

# %%
#data.to_csv('Tinder_Conv_Data_v4.csv', index=False)
